# %%
from transformers import AutoModelWithLMHead, AutoTokenizer
import torch

# %%
import re

def find_top(sentence, model, tokenizer, k): 
    print("Input: ", sentence)
    smatch = re.search("(\w+)\?", sentence)
    target = None
    
    if (smatch):
        target = re.sub("\?", "", smatch.group(0))
        
    sequence = re.sub("(\w+)?\?", tokenizer.mask_token, sentence)
    print(tokenizer.tokenize(sequence))
    
    input = tokenizer.encode(sequence, return_tensors="pt")
    mask_token_index = torch.where(input == tokenizer.mask_token_id)[1]

    token_logits = model(input)[0]
    mask_token_logits = token_logits[0, mask_token_index, :]

    topk = torch.topk(mask_token_logits, tokenizer.vocab_size, dim=1)
    top_tokens = list(zip(topk.indices[0].tolist(), topk.values[0].tolist()))

    for token, value in top_tokens[:k]:
        print(tokenizer.decode([token]), " ", value)
        
    if (target != None):
        vec = tokenizer.encode(target, return_tensors="pt")[0]
        if (len(vec) == 3):
            tk = vec[1].item()
            pos = None
            score = None
            
            for e, (t, v) in enumerate(top_tokens):
                if (t == tk):
                    pos = e
                    score = v
                    break
            print("Original word position: ", e, "; score: ", score)
        else: 
            if (len(vec) > 3):
                print("Original word is more then 1 token")
                print(tokenizer.tokenize(target))
            else:
                print("Original word wasn't found")
    print("===================")
    
def do_find(s):
    find_top(s, model,tokenizer, 10) 
    
base_samples = [
    "what's the local weather? forecast",
    "chance of rain? tomorrow in moscow",
    "chance of rain? tomorrow",
    "set the lights? on in the entire house",
    "set the lights on in the entire house?",
    "turn the lights off in the guest? bedroom",
    "turn the lights off in the guest bedroom?"
]

## Random wiki how to articles
articles = ["how to use a sharpening steel?",
"how to identify? and treat liver shunts in cats",
"how to identify and treat? liver shunts in cats",
"how to identify and treat liver? shunts in cats",
"how to identify and treat liver shunt? in cats",
"use enamel? paint on a stove",
"use enamel paint? on a stove",
"how to etch? wood",
"escape a sinking? ship",
"escape a sinking ship?",
"how to choose a cat? bed"]

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased")
model = AutoModelWithLMHead.from_pretrained("bert-large-uncased")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1344997306.0, style=ProgressStyle(descr…

# %%
for s in base_samples:
    do_find(s)
# Out:
# Input:  what's the local weather? forecast
# ['what', "'", 's', 'the', 'local', '[MASK]', 'forecast']
# weather   13.933197975158691
# wind   9.824950218200684
# storm   8.210029602050781
# climate   7.648484230041504
# tornado   7.5318193435668945
# traffic   7.494179725646973
# business   7.40327787399292
# news   7.227436542510986
# flood   7.180978298187256
# heat   7.1706132888793945
# Original word position:  0 ; score:  13.933197975158691
# ===================
# Input:  chance of rain? tomorrow in moscow
# ['chance', 'of', '[MASK]', 'tomorrow', 'in', 'moscow']
# meeting   9.252975463867188
# success   8.11396312713623
# working   7.349595069885254
# victory   7.223593235015869
# landing   7.137297630310059
# flying   6.959140777587891
# winning   6.743556976318359
# freedom   6.722757816314697
# action   6.516355037689209
# that   6.507873058319092
# Original word position:  205 ; score:  3.3014800548553467
# ===================
# Input:  chance of rain? tomorrow
# ['chance', 'of', '[MASK]', 'tomorrow']
# winning   8.949573516845703
# success   7.771795272827148
# returning   7.744257926940918
# flying   7.6221113204956055
# reelection   7.561379432678223
# victory   7.4334893226623535
# meeting   7.18866491317749
# starting   6.745697021484375
# survival   6.612527370452881
# action   6.507620334625244
# Original word position:  58 ; score:  4.856316566467285
# ===================
# Input:  set the lights? on in the entire house
# ['set', 'the', '[MASK]', 'on', 'in', 'the', 'entire', 'house']
# lights   13.092552185058594
# electricity   10.676838874816895
# heat   10.658750534057617
# tv   10.19982624053955
# light   9.824381828308105
# television   9.511091232299805
# furnace   8.881977081298828
# lamps   8.586431503295898
# water   8.472455978393555
# heating   8.470845222473145
# Original word position:  0 ; score:  13.092552185058594
# ===================
# Input:  set the lights on in the entire house?
# ['set', 'the', 'lights', 'on', 'in', 'the', 'entire', '[MASK]']
# .   14.503103256225586
# ;   11.974774360656738
# !   11.91604995727539
# ?   9.598828315734863
# |   8.505709648132324
# city   8.18765640258789
# village   6.988840103149414
# ...   6.85222864151001
# town   6.798156261444092
# building   6.610790729522705
# Original word position:  10 ; score:  6.391844272613525
# ===================
# Input:  turn the lights off in the guest? bedroom
# ['turn', 'the', 'lights', 'off', 'in', 'the', '[MASK]', 'bedroom']
# master   13.208529472351074
# spare   10.972299575805664
# guest   10.841778755187988
# upstairs   10.07520866394043
# other   9.686775207519531
# second   9.36362075805664
# downstairs   9.320876121520996
# main   9.114884376525879
# back   9.019060134887695
# first   9.00313949584961
# Original word position:  2 ; score:  10.841778755187988
# ===================
# Input:  turn the lights off in the guest bedroom?
# ['turn', 'the', 'lights', 'off', 'in', 'the', 'guest', '[MASK]']
# .   29.14101219177246
# ;   25.12178611755371
# !   19.864147186279297
# ?   18.58201789855957
# |   12.528237342834473
# ...   10.464526176452637
# -   9.315640449523926
# ,   9.078079223632812
# ।   9.031766891479492
# :   8.952903747558594
# Original word position:  398 ; score:  0.7595946788787842
# ===================

# %%
for a in articles:
    do_find(a)
# Out:
# Input:  how to use a sharpening steel?
# ['how', 'to', 'use', 'a', 'sharpe', '##ning', '[MASK]']
# .   26.010730743408203
# ;   24.789464950561523
# ?   19.370759963989258
# !   16.240190505981445
# |   11.801448822021484
# ...   10.177217483520508
# ,   9.878094673156738
# :   9.558690071105957
# -   9.409708976745605
# ।   7.7624125480651855
# Original word position:  8281 ; score:  -3.2654049396514893
# ===================
# Input:  how to identify? and treat liver shunts in cats
# ['how', 'to', '[MASK]', 'and', 'treat', 'liver', 'shu', '##nts', 'in', 'cats']
# identify   12.187110900878906
# detect   11.675525665283203
# prevent   11.412120819091797
# find   11.294748306274414
# make   11.01986312866211
# locate   10.963879585266113
# remove   10.463669776916504
# prepare   10.146129608154297
# measure   9.821012496948242
# repair   9.662485122680664
# Original word position:  0 ; score:  12.187110900878906
# ===================
# Input:  how to identify and treat? liver shunts in cats
# ['how', 'to', 'identify', 'and', '[MASK]', 'liver', 'shu', '##nts', 'in', 'cats']
# treat   11.370222091674805
# use   11.353108406066895
# repair   10.637520790100098
# measure   10.339524269104004
# correct   10.267936706542969
# maintain   10.183731079101562
# control   10.002527236938477
# avoid   9.969663619995117
# prevent   9.846213340759277
# detect   9.69349193572998
# Original word position:  0 ; score:  11.370222091674805
# ===================
# Input:  how to identify and treat liver? shunts in cats
# ['how', 'to', 'identify', 'and', 'treat', '[MASK]', 'shu', '##nts', 'in', 'cats']
# the   7.477731227874756
# air   6.971446990966797
# electrical   6.218512535095215
# lateral   6.072432994842529
# these   5.94256591796875
# traffic   5.917330265045166
# blood   5.842879772186279
# fluid   5.709868431091309
# heart   5.643124580383301
# head   5.624970436096191
# Original word position:  1583 ; score:  0.6590031385421753
# ===================
# Input:  how to identify and treat liver shunt? in cats
# ['how', 'to', 'identify', 'and', 'treat', 'liver', '[MASK]', 'in', 'cats']
# disease   16.692153930664062
# diseases   15.572763442993164
# tumors   14.163148880004883
# problems   14.004229545593262
# cancer   13.921186447143555
# disorders   12.716191291809082
# damage   11.899947166442871
# cancers   11.589795112609863
# tuberculosis   11.440735816955566
# conditions   11.377086639404297
# Original word is more then 1 token
# ['shu', '##nt']
# ===================
# Input:  use enamel? paint on a stove
# ['use', '[MASK]', 'paint', 'on', 'a', 'stove']
# spray   9.44631290435791
# white   8.854297637939453
# red   8.643115043640137
# oil   8.416252136230469
# black   8.370309829711914
# blue   7.606219291687012
# face   7.36546516418457
# colored   7.226235866546631
# a   7.200903415679932
# yellow   6.853501319885254
# Original word position:  100 ; score:  3.1668381690979004
# ===================
# Input:  use enamel paint? on a stove
# ['use', 'enamel', '[MASK]', 'on', 'a', 'stove']
# paint   11.484698295593262
# paints   10.977978706359863
# pots   10.140862464904785
# ##s   9.76047420501709
# ##ware   8.90373420715332
# ##ing   8.699910163879395
# ##ling   8.179993629455566
# enamel   8.001493453979492
# pot   7.861224174499512
# cooking   7.703065872192383
# Original word position:  0 ; score:  11.484698295593262
# ===================
# Input:  how to etch? wood
# ['how', 'to', '[MASK]', 'wood']
# make   12.283477783203125
# cut   11.933905601501465
# chop   11.458163261413574
# fire   10.239740371704102
# grind   9.89062213897705
# use   9.362846374511719
# build   9.26948070526123
# work   9.269216537475586
# burn   8.999909400939941
# cook   8.8635892868042
# Original word is more then 1 token
# ['etc', '##h']
# ===================
# Input:  escape a sinking? ship
# ['escape', 'a', '[MASK]', 'ship']
# sinking   10.878106117248535
# pirate   10.200408935546875
# prison   9.209766387939453
# burning   9.097916603088379
# strange   8.712786674499512
# cruise   8.663240432739258
# treasure   8.391328811645508
# cargo   8.242920875549316
# passing   8.010353088378906
# ghost   8.010269165039062
# Original word position:  0 ; score:  10.878106117248535
# ===================
# Input:  escape a sinking ship?
# ['escape', 'a', 'sinking', '[MASK]']
# .   26.181795120239258
# ;   25.433944702148438
# !   19.378726959228516
# ?   17.743005752563477
# |   15.26471996307373
# ...   9.675196647644043
# :   8.903000831604004
# ।   8.787052154541016
# ,   8.45141887664795
# -   8.3160982131958
# Original word position:  288 ; score:  1.2586431503295898
# ===================
# Input:  how to choose a cat? bed
# ['how', 'to', 'choose', 'a', '[MASK]', 'bed']
# comfortable   10.564725875854492
# proper   8.99305248260498
# suitable   8.532258987426758
# soft   8.45356273651123
# good   8.269048690795898
# new   8.168376922607422
# special   8.053420066833496
# particular   7.981888294219971
# single   7.950286388397217
# specific   7.7826828956604
# Original word position:  886 ; score:  1.4020899534225464
# ===================

# %%
tokenizer = AutoTokenizer.from_pretrained("roberta-large")
model = AutoModelWithLMHead.from_pretrained("roberta-large")

# %%
for s in base_samples:
    do_find(s)
# Out:
# Input:  what's the local weather? forecast
# ['what', "'s", 'Ġthe', 'Ġlocal', '<mask>', 'Ġforecast']
#  weather   58.944068908691406
#  temperature   55.825252532958984
#  snow   55.3741455078125
#  traffic   54.93745422363281
#  rainfall   54.863487243652344
#  rain   54.681884765625
#  school   54.495479583740234
#  weekend   54.44187545776367
#  precipitation   54.293479919433594
#  driving   54.13661193847656
# Original word position:  0 ; score:  58.944068908691406
# ===================
# Input:  chance of rain? tomorrow in moscow
# ['chance', 'Ġof', '<mask>', 'Ġtomorrow', 'Ġin', 'Ġmos', 'cow']
#  bulls   56.93559265136719
#  action   56.55562210083008
#  fireworks   56.390655517578125
#  beef   56.36457443237305
#  cattle   55.886962890625
#  thousands   55.69841003417969
#  events   55.575355529785156
#  cows   55.51642608642578
#  Beef   55.48601150512695
#  wrestling   55.44188690185547
# Original word position:  63 ; score:  54.1391487121582
# ===================
# Input:  chance of rain? tomorrow
# ['chance', 'Ġof', '<mask>', 'Ġtomorrow']
#  rain   59.147621154785156
#  snow   58.66455841064453
#  showers   57.471946716308594
#  storms   57.344703674316406
#  Rain   56.85991287231445
#  storm   56.51268005371094
#  day   56.399932861328125
#  weather   56.376609802246094
#  sunshine   56.30049133300781
#  fog   56.26933670043945
# Original word position:  0 ; score:  59.147621154785156
# ===================
# Input:  set the lights? on in the entire house
# ['set', 'Ġthe', '<mask>', 'Ġon', 'Ġin', 'Ġthe', 'Ġentire', 'Ġhouse']
#  lights   61.43402862548828
#  heat   60.002777099609375
#  AC   58.902503967285156
#  light   58.8398323059082
#  fans   58.78802490234375
#  water   58.59513854980469
#  fan   58.2420539855957
#  heating   58.154048919677734
#  electricity   58.07539367675781
#  power   57.6944580078125
# Original word position:  0 ; score:  61.43402862548828
# ===================
# Input:  set the lights on in the entire house?
# ['set', 'Ġthe', 'Ġlights', 'Ġon', 'Ġin', 'Ġthe', 'Ġentire', '<mask>']
#  room   63.75288009643555
#  house   63.09485626220703
#  building   61.1422004699707
#  area   60.69646453857422
#  office   60.46257781982422
#  basement   60.35721969604492
#  kitchen   60.338409423828125
#  apartment   60.14122772216797
#  bathroom   60.084224700927734
#  store   60.071903228759766
# Original word position:  1 ; score:  63.09485626220703
# ===================
# Input:  turn the lights off in the guest? bedroom
# ['turn', 'Ġthe', 'Ġlights', 'Ġoff', 'Ġin', 'Ġthe', '<mask>', 'Ġbedroom']
#  master   62.25900650024414
#  guest   60.62987518310547
#  second   59.89073181152344
#  spare   59.19243240356445
#  third   58.96836471557617
#  main   58.719661712646484
#  back   58.608848571777344
#  upstairs   58.48353576660156
#  other   58.32860565185547
#  front   58.00963592529297
# Original word position:  1 ; score:  60.62987518310547
# ===================
# Input:  turn the lights off in the guest bedroom?
# ['turn', 'Ġthe', 'Ġlights', 'Ġoff', 'Ġin', 'Ġthe', 'Ġguest', '<mask>']
#  room   62.96192169189453
#  rooms   61.589881896972656
#  bedroom   61.55071258544922
#  bathroom   60.759788513183594
# room   60.061004638671875
#  bedrooms   59.70532989501953
# rooms   59.17346954345703
#  bath   58.98833465576172
#  area   58.70155334472656
#  house   58.139278411865234
# Original word position:  2 ; score:  61.55071258544922
# ===================

# %%
for a in articles:
    do_find(a)
# Out:
# Input:  how to use a sharpening steel?
# ['how', 'Ġto', 'Ġuse', 'Ġa', 'Ġsharp', 'ening', '<mask>']
#  tool   55.64176940917969
#  knife   55.36676788330078
#  pencil   55.1890869140625
#  iron   54.96471405029297
#  stone   54.86848449707031
#  wheel   54.341529846191406
#  pen   53.8603401184082
#  device   53.61422348022461
#  brush   53.129844665527344
#  blade   52.88595199584961
# Original word position:  16 ; score:  52.06224060058594
# ===================
# Input:  how to identify? and treat liver shunts in cats
# ['how', 'Ġto', '<mask>', 'Ġand', 'Ġtreat', 'Ġliver', 'Ġshun', 'ts', 'Ġin', 'Ġcats']
#  diagnose   61.9696159362793
#  spot   60.435420989990234
#  prevent   60.22199249267578
#  identify   59.7053337097168
#  detect   59.45398712158203
#  find   59.16080856323242
#  recognize   58.65917205810547
#  monitor   57.187862396240234
#  catch   57.06170654296875
#  locate   56.8363151550293
# Original word position:  3 ; score:  59.7053337097168
# ===================
# Input:  how to identify and treat? liver shunts in cats
# ['how', 'Ġto', 'Ġidentify', 'Ġand', '<mask>', 'Ġliver', 'Ġshun', 'ts', 'Ġin', 'Ġcats']
#  treat   62.69602584838867
#  manage   59.27101135253906
#  prevent   59.01032257080078
#  repair   58.93404006958008
#  remove   58.8764533996582
#  diagnose   58.35043716430664
#  track   57.797760009765625
#  stop   57.513370513916016
#  monitor   57.48232650756836
#  cure   57.30830383300781
# Original word position:  0 ; score:  62.69602584838867
# ===================
# Input:  how to identify and treat liver? shunts in cats
# ['how', 'Ġto', 'Ġidentify', 'Ġand', 'Ġtreat', '<mask>', 'Ġshun', 'ts', 'Ġin', 'Ġcats']
#  urinary   57.66912841796875
#  tail   56.32952880859375
#  thyroid   56.214561462402344
#  ear   55.9168586730957
#  head   55.726505279541016
#  respiratory   55.549556732177734
#  heart   55.48444366455078
#  liver   55.418087005615234
#  intestinal   55.3883056640625
#  nasal   55.30845260620117
# Original word position:  7 ; score:  55.418087005615234
# ===================
# Input:  how to identify and treat liver shunt? in cats
# ['how', 'Ġto', 'Ġidentify', 'Ġand', 'Ġtreat', 'Ġliver', '<mask>', 'Ġin', 'Ġcats']
#  cancer   57.72657775878906
#  disease   57.64242935180664
#  tumors   56.39731979370117
#  failure   56.11973571777344
#  diseases   55.73298645019531
#  damage   55.716312408447266
#  problems   55.332740783691406
#  disorders   54.86365509033203
#  infections   54.47181701660156
#  inflammation   54.390403747558594
# Original word is more then 1 token
# ['sh', 'unt']
# ===================
# Input:  use enamel? paint on a stove
# ['use', '<mask>', 'Ġpaint', 'Ġon', 'Ġa', 'Ġstove']
# ing   51.16877746582031
# earing   51.069889068603516
# ouring   50.757572174072266
#  spray   50.669254302978516
# aking   50.44495391845703
# ting   49.998085021972656
# ashing   49.95427322387695
# ling   49.83500289916992
# ating   49.81758117675781
#  to   49.760948181152344
# Original word is more then 1 token
# ['en', 'amel']
# ===================
# Input:  use enamel paint? on a stove
# ['use', 'Ġen', 'amel', '<mask>', 'Ġon', 'Ġa', 'Ġstove']
#  pot   56.878082275390625
#  pan   56.84223937988281
#  pots   56.62730407714844
# ed   55.75200271606445
#  pans   55.688629150390625
#  jars   55.5319709777832
#  coating   55.353050231933594
#  jar   54.916481018066406
#  oil   54.78541946411133
#  paint   54.7498779296875
# Original word position:  9 ; score:  54.7498779296875
# ===================
# Input:  how to etch? wood
# ['how', 'Ġto', '<mask>', 'Ġwood']
#  buy   56.54882049560547
#  cut   56.37584686279297
#  chop   56.09185791015625
#  get   56.01765441894531
#  gather   55.60955047607422
#  use   55.29740905761719
#  find   55.19351577758789
#  burn   55.05069351196289
#  collect   55.034725189208984
#  dry   54.9294548034668
# Original word is more then 1 token
# ['etch']
# ===================
# Input:  escape a sinking? ship
# ['escape', 'Ġa', '<mask>', 'Ġship']
#  cruise   58.42720413208008
#  cargo   56.786293029785156
#  pirate   56.477928161621094
#  sinking   56.103729248046875
#  container   55.70797348022461
#  small   55.65782165527344
#  tall   55.656585693359375
#  ghost   55.45624542236328
#  passenger   55.334571838378906
#  new   55.228729248046875
# Original word position:  3 ; score:  56.103729248046875
# ===================
# Input:  escape a sinking ship?
# ['escape', 'Ġa', 'Ġsinking', '<mask>']
#  ship   61.24334716796875
#  boat   58.3192024230957
#  vessel   57.68462371826172
#  world   56.740116119384766
#  economy   56.637725830078125
#  city   56.406768798828125
#  Ship   56.07484817504883
#  planet   56.0037956237793
#  train   55.959293365478516
#  Titanic   55.89506912231445
# Original word position:  0 ; score:  61.24334716796875
# ===================
# Input:  how to choose a cat? bed
# ['how', 'Ġto', 'Ġchoose', 'Ġa', '<mask>', 'Ġbed']
#  good   55.047176361083984
#  new   53.81332015991211
#  comfortable   53.7047119140625
#  bunk   53.5877571105957
#  hospital   53.39140319824219
#  canopy   52.61083221435547
#  hotel   52.408287048339844
#  cheap   52.37895202636719
#  solid   52.173709869384766
#  dream   52.082672119140625
# Original word position:  275 ; score:  48.02002716064453
# ===================

# %%
tokenizer = AutoTokenizer.from_pretrained("flaubert-large-cased")
model = AutoModelWithLMHead.from_pretrained("flaubert-large-cased")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1030.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1561415.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=895731.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1493194721.0, style=ProgressStyle(descr…

# %%
for s in base_samples:
    do_find(s)
# Out:
# Input:  what's the local weather? forecast
# ['wh', 'at', "'</w>", 's</w>', 'the</w>', 'local</w>', '<special1>', 'for', 'ec', 'ast</w>']
# change   16.84689712524414
# time   15.88947582244873
# for   15.521727561950684
# if   15.50067138671875
# next   15.128596305847168
# "   14.749134063720703
# second   14.658276557922363
# re   14.613921165466309
# in   14.404990196228027
# ,   14.119577407836914
# Original word is more then 1 token
# ['we', 'ather</w>']
# ===================
# Input:  chance of rain? tomorrow in moscow
# ['chance</w>', 'of</w>', '<special1>', 'tom', 'or', 'row</w>', 'in</w>', 'mos', 'co', 'w</w>']
# for   17.209707260131836
# to   16.50912857055664
# in   16.4116268157959
# bury   16.273530960083008
# end   16.26807403564453
# be   16.241287231445312
# play   16.057323455810547
# even   15.000792503356934
# three   14.698225021362305
# the   14.340210914611816
# Original word position:  86 ; score:  10.30911922454834
# ===================
# Input:  chance of rain? tomorrow
# ['chance</w>', 'of</w>', '<special1>', 'tom', 'or', 'row</w>']
# for   17.60697364807129
# to   17.55022430419922
# bury   16.244306564331055
# in   15.878832817077637
# be   15.431715965270996
# the   15.416617393493652
# life   14.991558074951172
# of   14.630407333374023
# and   14.314870834350586
# time   13.998620986938477
# Original word position:  70 ; score:  10.430963516235352
# ===================
# Input:  set the lights? on in the entire house
# ['set</w>', 'the</w>', '<special1>', 'on</w>', 'in</w>', 'the</w>', 'enti', 're</w>', 'house</w>']
# bat   18.547136306762695
# to   16.919742584228516
# man   16.40596580505371
# comm   16.26219940185547
# bi   16.231586456298828
# all   16.073204040527344
# fr   15.740717887878418
# hav   15.654876708984375
# batt   15.639416694641113
# pers   15.475610733032227
# Original word is more then 1 token
# ['li', 'ghts</w>']
# ===================
# Input:  set the lights on in the entire house?
# ['set</w>', 'the</w>', 'li', 'ghts</w>', 'on</w>', 'in</w>', 'the</w>', 'enti', 're</w>', '<special1>']
# pan   12.78901195526123
# ,   11.475167274475098
# second   10.963337898254395
# self   10.858779907226562
# and   9.775262832641602
# after   9.600110054016113
# pièce   9.440001487731934
# four   9.342140197753906
# a   9.288704872131348
# in   9.242569923400879
# Original word position:  16661 ; score:  -3.814901828765869
# ===================
# Input:  turn the lights off in the guest? bedroom
# ['turn</w>', 'the</w>', 'li', 'ghts</w>', 'off</w>', 'in</w>', 'the</w>', '<special1>', 'be', 'dro', 'om</w>']
# second   21.553834915161133
# first   19.417911529541016
# double   18.60845184326172
# home   18.42202377319336
# dressing   17.840620040893555
# door   17.417736053466797
# four   16.905925750732422
# positive   16.725893020629883
# triple   16.39849853515625
# two   16.09001350402832
# Original word is more then 1 token
# ['gu', 'est</w>']
# ===================
# Input:  turn the lights off in the guest bedroom?
# ['turn</w>', 'the</w>', 'li', 'ghts</w>', 'off</w>', 'in</w>', 'the</w>', 'gu', 'est</w>', '<special1>']
# off   13.9705171585083
# in   12.99123764038086
# of   12.705705642700195
# and   12.070549964904785
# for   12.02690315246582
# class   11.785058975219727
# by   11.679864883422852
# ,   11.114483833312988
# that   11.021480560302734
# home   11.002375602722168
# Original word is more then 1 token
# ['be', 'dro', 'om</w>']
# ===================

# %%
for a in articles:
    do_find(a)
# Out:
# Input:  how to use a sharpening steel?
# ['how</w>', 'to</w>', 'use</w>', 'a</w>', 'shar', 'pen', 'ing</w>', '<special1>']
# for   15.021530151367188
# body   12.83782958984375
# ,   12.724711418151855
# fruit   11.820119857788086
# to   11.552226066589355
# of   11.362137794494629
# ver   11.32625961303711
# in   11.12248706817627
# and   11.064708709716797
# support   11.035231590270996
# Original word is more then 1 token
# ['ste', 'el</w>']
# ===================
# Input:  how to identify? and treat liver shunts in cats
# ['how</w>', 'to</w>', '<special1>', 'and</w>', 'tre', 'at</w>', 'li', 'ver</w>', 'sh', 'un', 'ts</w>', 'in</w>', 'cats</w>']
# sex   17.300159454345703
# use   14.001256942749023
# cure   13.8759765625
# lave   13.508421897888184
# girls   12.985353469848633
# and   12.805550575256348
# fine   12.574772834777832
# div   12.547651290893555
# stream   12.534297943115234
# pr   12.533191680908203
# Original word is more then 1 token
# ['identi', 'fy</w>']
# ===================
# Input:  how to identify and treat? liver shunts in cats
# ['how</w>', 'to</w>', 'identi', 'fy</w>', 'and</w>', '<special1>', 'li', 'ver</w>', 'sh', 'un', 'ts</w>', 'in</w>', 'cats</w>']
# and   14.903011322021484
# the   14.634849548339844
# fol   13.58962631225586
# or   13.48576545715332
# to   13.256875991821289
# cel   13.168476104736328
# for   12.936823844909668
# of   12.824492454528809
# a   12.580988883972168
# six   11.997052192687988
# Original word is more then 1 token
# ['tre', 'at</w>']
# ===================
# Input:  how to identify and treat liver? shunts in cats
# ['how</w>', 'to</w>', 'identi', 'fy</w>', 'and</w>', 'tre', 'at</w>', '<special1>', 'sh', 'un', 'ts</w>', 'in</w>', 'cats</w>']
# or   20.21926498413086
# of   19.490562438964844
# into   18.722719192504883
# for   18.532634735107422
# by   17.851306915283203
# the   17.83998680114746
# and   17.779891967773438
# off   17.553876876831055
# to   16.781375885009766
# from   15.749911308288574
# Original word is more then 1 token
# ['li', 'ver</w>']
# ===================
# Input:  how to identify and treat liver shunt? in cats
# ['how</w>', 'to</w>', 'identi', 'fy</w>', 'and</w>', 'tre', 'at</w>', 'li', 'ver</w>', '<special1>', 'in</w>', 'cats</w>']
# and   15.788337707519531
# th   15.313210487365723
# hav   15.226163864135742
# or   14.609999656677246
# ve   13.263863563537598
# ke   13.240317344665527
# for   12.977791786193848
# car   12.887168884277344
# by   12.851492881774902
# in   12.848191261291504
# Original word is more then 1 token
# ['sh', 'unt</w>']
# ===================
# Input:  use enamel? paint on a stove
# ['use</w>', '<special1>', 'p', 'aint</w>', 'on</w>', 'a</w>', 'sto', 've</w>']
# ,   13.014063835144043
# de   12.383896827697754
# se   11.581995964050293
# le   11.563343048095703
# on   11.499074935913086
# du   11.182156562805176
# en   10.92193603515625
# vo   10.378124237060547
# au   10.288835525512695
# com   10.280935287475586
# Original word is more then 1 token
# ['en', 'amel</w>']
# ===================
# Input:  use enamel paint? on a stove
# ['use</w>', 'en', 'amel</w>', '<special1>', 'on</w>', 'a</w>', 'sto', 've</w>']
# ,   12.14626693725586
# l'   10.432876586914062
# bu   9.484054565429688
# qu'   9.445077896118164
# on   9.4103422164917
# I   9.270672798156738
# d'   9.254891395568848
# o   9.240280151367188
# ai   9.20071029663086
# se   8.91015625
# Original word is more then 1 token
# ['p', 'aint</w>']
# ===================
# Input:  how to etch? wood
# ['how</w>', 'to</w>', '<special1>', 'wood</w>']
# be   19.602088928222656
# my   19.413267135620117
# end   18.98900604248047
# be   17.860065460205078
# ver   17.693347930908203
# the   17.17241096496582
# wood   17.126367568969727
# to   16.745058059692383
# by   16.56528091430664
# that   16.531885147094727
# Original word position:  5003 ; score:  -1.9512051343917847
# ===================
# Input:  escape a sinking? ship
# ['es', 'cape</w>', 'a</w>', '<special1>', 'ship</w>']
# close   15.535726547241211
# clo   15.032318115234375
# tis   14.418265342712402
# to   14.258198738098145
# cape   13.7666654586792
# cross   13.644720077514648
# port   13.143267631530762
# extension   12.99641227722168
# ar   12.854557037353516
# pan   12.587057113647461
# Original word is more then 1 token
# ['sin', 'king</w>']
# ===================
# Input:  escape a sinking ship?
# ['es', 'cape</w>', 'a</w>', 'sin', 'king</w>', '<special1>']
# to   14.353015899658203
# of   13.564821243286133
# for   13.250728607177734
# ,   12.1155366897583
# or   11.637551307678223
# the   11.635897636413574
# our   11.556532859802246
# ver   11.304824829101562
# one   11.09751033782959
# in   10.981527328491211
# Original word position:  1446 ; score:  2.7047617435455322
# ===================
# Input:  how to choose a cat? bed
# ['how</w>', 'to</w>', 'cho', 'ose</w>', 'a</w>', '<special1>', 'b', 'ed</w>']
# ci   14.327312469482422
# for   13.863479614257812
# cross   13.548908233642578
# my   13.325295448303223
# ham   12.463099479675293
# gar   12.416764259338379
# cri   11.952038764953613
# ver   11.872462272644043
# ver   11.853340148925781
# social   11.765419960021973
# Original word position:  211 ; score:  7.245361804962158
# ===================
